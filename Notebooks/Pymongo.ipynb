# %% [markdown]
# # Pymongo pulls

# %%
import pymongo

# %%
import json

# %%
dbuser = "MikeT"
dbpassword = "MikeT123"

# %%
# Configure connection
conn = f"mongodb://{dbuser}:{dbpassword}@ds135724.mlab.com:35724/global_terror"
mongoClient = pymongo.MongoClient(conn)
db = mongoClient.global_terror
col = db["terror_collection"]

# %%
query = {"properties.year":2017}
paramDict = {
    "_id": False,
    "type": True,
    "geometry": True,
    "properties": True
    }
result = col.find(query, paramDict)

# %%
result

# %%
geo2017 = []
for atk in result: 
    geo2017.append(atk)

# %%
geo2017
# Out:
# [{'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [31.320556, 65.961111]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 2,
#    'country_name': 'Afghanistan',
#    'city': 'Takhta Pul',
#    'attack_type': 'Hostage Taking (Kidnapping)',
#    'target_type': 'Business'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [12.921007, 24.318324]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 3,
#    'country_name': 'Sudan',
#    'city': 'Fantaga',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [1.452372, 29.875162]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 1,
#    'country_name': 'Democratic Republic of the Congo',
#    'city': 'Saboko',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [1.45237, 29.875186]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 1,
#    'country_name': 'Democratic Republic of the Congo',
#    'city': 'Bialee',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [41.106178, 28.689863]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 1,
#    'country_name': 'Turkey',
#    'city': 'Istanbul',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Business'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [34.895928, 35.886652]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 1,
#    'country_name': 'Syria',
#    'city': 'Tartus',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Police'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [34.824085, 71.382386]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 1,
#    'country_name': 'Pakistan',
#    'city': 'Niaag Bandar',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Police'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [43.76956, 11.255814]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 1,
#    'country_name': 'Italy',
#    'city': 'Florence',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Business'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [37.724137, 40.413484]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 1,
#    'country_name': 'Turkey',
#    'city': 'Cinar',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Police'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [41.106178, 28.689863]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 1,
#    'country_name': 'Turkey',
#    'city': 'Istanbul',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Religious Figures/Institutions'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [3.798013, 42.544463]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 1,
#    'country_name': 'Somalia',
#    'city': 'Luq district',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [32.90382, 70.535789]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 1,
#    'country_name': 'Pakistan',
#    'city': 'Nurar',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Educational Institution'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [13.586484, 44.024105]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 1,
#    'country_name': 'Yemen',
#    'city': 'Taizz',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [34.346722, 62.197315]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 1,
#    'country_name': 'Afghanistan',
#    'city': 'Herat',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Religious Figures/Institutions'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [26.0, 50.616667]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 1,
#    'country_name': 'Bahrain',
#    'city': 'Jaww',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Police'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [20.366728, 93.266651]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 1,
#    'country_name': 'Myanmar',
#    'city': 'Minbya',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Unknown'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [31.467463, 64.092445]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 1,
#    'country_name': 'Afghanistan',
#    'city': 'Marjah',
#    'attack_type': 'Unknown',
#    'target_type': 'Police'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [32.071931, 64.838837]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 1,
#    'country_name': 'Afghanistan',
#    'city': 'Sangin',
#    'attack_type': 'Unknown',
#    'target_type': 'Government (General)'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [34.34013, 63.75288]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 1,
#    'country_name': 'Afghanistan',
#    'city': 'Chishti Sharif district',
#    'attack_type': 'Hostage Taking (Kidnapping)',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.79821, 68.93483]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 1,
#    'country_name': 'Afghanistan',
#    'city': 'Charkh',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [12.959799, 24.039829]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 1,
#    'country_name': 'Sudan',
#    'city': 'Nertiti',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-3.375828, 29.364107]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 1,
#    'country_name': 'Burundi',
#    'city': 'Bujumbura',
#    'attack_type': 'Assassination',
#    'target_type': 'Government (General)'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [31.697046, 44.47716]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 1,
#    'country_name': 'Iraq',
#    'city': 'Qadisiyah',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Police'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.084629, 31.334314]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 1,
#    'country_name': 'Egypt',
#    'city': 'Cairo',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.200819, 66.994354]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 2,
#    'country_name': 'Pakistan',
#    'city': 'Quetta',
#    'attack_type': 'Hostage Taking (Kidnapping)',
#    'target_type': 'Government (General)'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [14.119094, -1.515526]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 1,
#    'country_name': 'Burkina Faso',
#    'city': 'Sibe',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Religious Figures/Institutions'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [14.093442, -1.634078]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 1,
#    'country_name': 'Burkina Faso',
#    'city': 'Djibo',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [9.873252, 76.302937]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 1,
#    'country_name': 'India',
#    'city': 'Aroor',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Government (General)'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [36.354145, 43.14357]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 1,
#    'country_name': 'Iraq',
#    'city': 'Mosul',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Unknown'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.542622, 68.415329]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 1,
#    'country_name': 'Afghanistan',
#    'city': 'Ghazni',
#    'attack_type': 'Hostage Taking (Kidnapping)',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.200819, 66.994354]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 2,
#    'country_name': 'Pakistan',
#    'city': 'Quetta',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [2.002975, 45.273875]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 2,
#    'country_name': 'Somalia',
#    'city': 'Mogadishu',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [2.059819, 45.326115]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 2,
#    'country_name': 'Somalia',
#    'city': 'Mogadishu',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Business'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [28.776834, 68.381625]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 2,
#    'country_name': 'Pakistan',
#    'city': 'Kanri',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Transportation'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [28.776834, 68.381625]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 2,
#    'country_name': 'Pakistan',
#    'city': 'Chattar',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [34.214801, 69.098513]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 2,
#    'country_name': 'Afghanistan',
#    'city': 'Mohammad Agha district',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Police'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [20.3335, 93.003812]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 2,
#    'country_name': 'Myanmar',
#    'city': 'Ponnagyun',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Unknown'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [36.354145, 43.14357]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 2,
#    'country_name': 'Iraq',
#    'city': 'Mosul',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Unknown'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [35.499439, 43.234894]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 2,
#    'country_name': 'Iraq',
#    'city': 'Shirqat',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.303566, 44.371773]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 2,
#    'country_name': 'Iraq',
#    'city': 'Baghdad',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.303566, 44.371773]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 2,
#    'country_name': 'Iraq',
#    'city': 'Baghdad',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Business'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.303566, 44.371773]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 2,
#    'country_name': 'Iraq',
#    'city': 'Baghdad',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.303566, 44.371773]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 2,
#    'country_name': 'Iraq',
#    'city': 'Baghdad',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.303566, 44.371773]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 2,
#    'country_name': 'Iraq',
#    'city': 'Baghdad',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Business'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.303566, 44.371773]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 2,
#    'country_name': 'Iraq',
#    'city': 'Baghdad',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Religious Figures/Institutions'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [34.92485, 43.491413]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 2,
#    'country_name': 'Iraq',
#    'city': 'Baiji',
#    'attack_type': 'Unknown',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [34.275066, 44.537865]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 2,
#    'country_name': 'Iraq',
#    'city': 'Adhaim',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Terrorists/Non-State Militia'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [34.275066, 44.537865]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 2,
#    'country_name': 'Iraq',
#    'city': 'Adhaim',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Terrorists/Non-State Militia'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [34.208416, 43.890713]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 2,
#    'country_name': 'Iraq',
#    'city': 'Samarra',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Police'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [34.208416, 43.890713]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 2,
#    'country_name': 'Iraq',
#    'city': 'Samarra',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Police'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-3.509014, 29.464359]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 2,
#    'country_name': 'Burundi',
#    'city': 'Unknown',
#    'attack_type': 'Hostage Taking (Kidnapping)',
#    'target_type': 'Violent Political Party'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [34.966667, 69.566667]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 2,
#    'country_name': 'Afghanistan',
#    'city': 'Nijrab district',
#    'attack_type': 'Assassination',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [2.059819, 45.326115]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 2,
#    'country_name': 'Somalia',
#    'city': 'Mogadishu',
#    'attack_type': 'Unknown',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [34.87048, 62.50668]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 2,
#    'country_name': 'Afghanistan',
#    'city': 'Koshki Kohna district',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [32.519241, 67.416481]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 2,
#    'country_name': 'Afghanistan',
#    'city': 'Shahjoy district',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Unknown'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [36.466727, 2.689879]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 2,
#    'country_name': 'Algeria',
#    'city': 'Mouzaia',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [41.842602, -87.681229]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 2,
#    'country_name': 'United States',
#    'city': 'Chicago',
#    'attack_type': 'Hostage Taking (Kidnapping)',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [7.740712, 123.076513]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 2,
#    'country_name': 'Philippines',
#    'city': 'Basalem',
#    'attack_type': 'Assassination',
#    'target_type': 'Government (General)'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [8.864636, 77.496008]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 2,
#    'country_name': 'India',
#    'city': 'Alangulam',
#    'attack_type': 'Assassination',
#    'target_type': 'Government (General)'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [37.99749, 23.762728]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 3,
#    'country_name': 'Greece',
#    'city': 'Athens',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Government (General)'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [24.663717, 93.906269]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 2,
#    'country_name': 'India',
#    'city': 'Unknown',
#    'attack_type': 'Unknown',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [15.075, -2.221111]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 2,
#    'country_name': 'Mali',
#    'city': 'Boni',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [35.466624, 43.238815]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 2,
#    'country_name': 'Iraq',
#    'city': 'Shirqat district',
#    'attack_type': 'Unknown',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [13.883333, 45.866667]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 3,
#    'country_name': 'Yemen',
#    'city': 'Lawdar district',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [34.075466, 71.599998]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 3,
#    'country_name': 'Pakistan',
#    'city': 'Khazana',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Police'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [31.164289, 16.887761]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 3,
#    'country_name': 'Libya',
#    'city': 'Unknown',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Religious Figures/Institutions'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [25.530286, 63.415847]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 3,
#    'country_name': 'Pakistan',
#    'city': 'Kech district',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Business'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [6.741797, 122.398145]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 3,
#    'country_name': 'Philippines',
#    'city': 'Unknown',
#    'attack_type': 'Hijacking',
#    'target_type': 'Maritime'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [6.253713, 25.473355]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 3,
#    'country_name': 'Central African Republic',
#    'city': 'Unknown',
#    'attack_type': 'Unknown',
#    'target_type': 'Government (Diplomatic)'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [6.879722, 15.554444]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 3,
#    'country_name': 'Central African Republic',
#    'city': 'Bokaya',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Government (Diplomatic)'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [29.360998, 30.68244]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 3,
#    'country_name': 'Egypt',
#    'city': 'Ibsheway',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Police'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [25.749567, 86.006417]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 3,
#    'country_name': 'India',
#    'city': 'Salakhani',
#    'attack_type': 'Assassination',
#    'target_type': 'Journalists & Media'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [36.370146, 66.891581]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 3,
#    'country_name': 'Afghanistan',
#    'city': 'Qadim',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [31.65, 65.65]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 3,
#    'country_name': 'Afghanistan',
#    'city': 'Arghandab district',
#    'attack_type': 'Unarmed Assault',
#    'target_type': 'Police'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [31.631083, 65.742226]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 3,
#    'country_name': 'Afghanistan',
#    'city': 'Kandahar',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.306127, 62.156823]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 3,
#    'country_name': 'Afghanistan',
#    'city': 'Shindand district',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Unknown'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [10.890928, 13.627589]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 3,
#    'country_name': 'Nigeria',
#    'city': 'Dar',
#    'attack_type': 'Hostage Taking (Kidnapping)',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.409771, 43.198972]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 3,
#    'country_name': 'Iraq',
#    'city': 'Ramadi',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [36.354145, 43.14357]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 3,
#    'country_name': 'Iraq',
#    'city': 'Mosul',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [36.354145, 43.14357]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 3,
#    'country_name': 'Iraq',
#    'city': 'Mosul',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [36.354145, 43.14357]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 3,
#    'country_name': 'Iraq',
#    'city': 'Mosul',
#    'attack_type': 'Unknown',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.86652, 74.864548]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 3,
#    'country_name': 'India',
#    'city': 'Murran',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Police'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [31.200092, 29.918739]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 3,
#    'country_name': 'Egypt',
#    'city': 'Alexandria',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Business'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.542004, 35.381153]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 3,
#    'country_name': 'Lebanon',
#    'city': 'Ain al-Hilweh',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [23.65, 85.0]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 3,
#    'country_name': 'India',
#    'city': 'Khelari',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Business'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [28.994965, 68.348482]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 3,
#    'country_name': 'Pakistan',
#    'city': 'Phuleji',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Unknown'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [28.869226, 68.334419]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 3,
#    'country_name': 'Pakistan',
#    'city': 'Chattar',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Unknown'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [25.426636, -100.995363]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 3,
#    'country_name': 'Mexico',
#    'city': 'Saltillo',
#    'attack_type': 'Hostage Taking (Kidnapping)',
#    'target_type': 'Religious Figures/Institutions'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [37.101709, 70.555236]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 3,
#    'country_name': 'Afghanistan',
#    'city': 'Faizabad district',
#    'attack_type': 'Unknown',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [31.589827, 64.337952]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 2,
#    'country_name': 'Afghanistan',
#    'city': 'Bolan',
#    'attack_type': 'Unknown',
#    'target_type': 'Police'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [36.420649, 69.35927]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 3,
#    'country_name': 'Afghanistan',
#    'city': 'Ishkamish district',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Unknown'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [31.203173, 16.643446]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 4,
#    'country_name': 'Libya',
#    'city': 'Sirte',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [36.354145, 43.14357]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 4,
#    'country_name': 'Iraq',
#    'city': 'Mosul',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Unknown'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [36.354145, 43.14357]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 4,
#    'country_name': 'Iraq',
#    'city': 'Mosul',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.426248, 42.977081]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 4,
#    'country_name': 'Iraq',
#    'city': 'Wafa',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [28.923056, 68.328611]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 4,
#    'country_name': 'Pakistan',
#    'city': 'Tahir Kot',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Unknown'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [28.869226, 68.334419]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 4,
#    'country_name': 'Pakistan',
#    'city': 'Chattar',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Utilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.200819, 66.994354]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 4,
#    'country_name': 'Pakistan',
#    'city': 'Quetta',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Police'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [7.065261, 124.961053]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 4,
#    'country_name': 'Philippines',
#    'city': 'Amas',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Police'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [None, None]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 4,
#    'country_name': 'Cameroon',
#    'city': 'Unknown',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [34.92485, 43.491413]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 4,
#    'country_name': 'Iraq',
#    'city': 'Baiji',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.326099, 68.416649]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 4,
#    'country_name': 'Afghanistan',
#    'city': 'Habib',
#    'attack_type': 'Assassination',
#    'target_type': 'Government (General)'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [35.018158, 69.168991]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 4,
#    'country_name': 'Afghanistan',
#    'city': 'Charikar',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [2.059819, 45.326115]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 4,
#    'country_name': 'Somalia',
#    'city': 'Mogadishu',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Government (Diplomatic)'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [2.925025, 45.903969]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 4,
#    'country_name': 'Somalia',
#    'city': 'Mirrtaqwa',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [11.592294, 37.3826]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 4,
#    'country_name': 'Ethiopia',
#    'city': 'Bahir Dar',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Business'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [31.834328, 70.90905]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 4,
#    'country_name': 'Pakistan',
#    'city': 'Dera Ismail Khan',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Police'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [24.891115, 67.143311]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 4,
#    'country_name': 'Pakistan',
#    'city': 'Karachi',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Police'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [24.891115, 67.143311]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 4,
#    'country_name': 'Pakistan',
#    'city': 'Karachi',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Business'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [23.166667, 79.933333]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 4,
#    'country_name': 'India',
#    'city': 'Jabalpur',
#    'attack_type': 'Assassination',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [34.468799, 36.041834]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 4,
#    'country_name': 'Lebanon',
#    'city': 'Bzal',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Government (General)'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [16.263981, -0.027987]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 4,
#    'country_name': 'Mali',
#    'city': 'Gao',
#    'attack_type': 'Armed Assault',
#    'target_type': 'NGO'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [10.842934, 13.483585]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 4,
#    'country_name': 'Nigeria',
#    'city': 'Bakin Dutse',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [11.089722, 13.688377]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 4,
#    'country_name': 'Nigeria',
#    'city': 'Gwoza district',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.043201, 44.641945]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 4,
#    'country_name': 'Iraq',
#    'city': 'Khanasah',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Business'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.185299, 44.26778]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 4,
#    'country_name': 'Iraq',
#    'city': 'Radhwaniyah',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.542622, 68.415329]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 4,
#    'country_name': 'Afghanistan',
#    'city': 'Ghazni',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Police'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [17.474068, 97.802248]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 4,
#    'country_name': 'Myanmar',
#    'city': 'Hlaingbwe',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [23.369968, 85.325012]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 4,
#    'country_name': 'India',
#    'city': 'Patehl',
#    'attack_type': 'Hostage Taking (Kidnapping)',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [37.99749, 23.762728]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 4,
#    'country_name': 'Greece',
#    'city': 'Athens',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'NGO'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [37.99749, 23.762728]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 4,
#    'country_name': 'Greece',
#    'city': 'Athens',
#    'attack_type': 'Facility/Infrastructure Attack',
#    'target_type': 'Business'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [42.874722, 74.612222]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 4,
#    'country_name': 'Kyrgyzstan',
#    'city': 'Bishkek',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Business'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [13.314837, 25.088934]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 4,
#    'country_name': 'Sudan',
#    'city': 'Tabit',
#    'attack_type': 'Facility/Infrastructure Attack',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [34.520279, 37.630001]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 4,
#    'country_name': 'Syria',
#    'city': 'Tiyas',
#    'attack_type': 'Unknown',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [15.075623, -2.219977]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 4,
#    'country_name': 'Mali',
#    'city': 'Boni',
#    'attack_type': 'Hostage Taking (Kidnapping)',
#    'target_type': 'Government (General)'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [5.788824, 6.100338]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 4,
#    'country_name': 'Nigeria',
#    'city': 'Abraka',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [5.838492, 6.158714]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 4,
#    'country_name': 'Nigeria',
#    'city': 'Obiaruku',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [32.069286, 20.151144]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 5,
#    'country_name': 'Libya',
#    'city': 'Benghazi',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.585, 66.8725]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 5,
#    'country_name': 'Pakistan',
#    'city': 'Saranan',
#    'attack_type': 'Assassination',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.303566, 44.371773]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 5,
#    'country_name': 'Iraq',
#    'city': 'Baghdad',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.303566, 44.371773]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 5,
#    'country_name': 'Iraq',
#    'city': 'Baghdad',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.303566, 44.371773]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 5,
#    'country_name': 'Iraq',
#    'city': 'Baghdad',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [34.705948, 43.697075]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 5,
#    'country_name': 'Iraq',
#    'city': 'Alam',
#    'attack_type': 'Assassination',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [31.429741, 64.303745]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 2,
#    'country_name': 'Afghanistan',
#    'city': 'Nawa-i-Barakzayi district',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Police'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [38.478577, 27.139976]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 5,
#    'country_name': 'Turkey',
#    'city': 'Izmir',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Government (General)'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [35.687365, 64.293428]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 5,
#    'country_name': 'Afghanistan',
#    'city': 'Qaysar',
#    'attack_type': 'Assassination',
#    'target_type': 'Police'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [34.417122, 70.449593]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 5,
#    'country_name': 'Afghanistan',
#    'city': 'Jalalabad',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [12.725161, 43.494482]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 5,
#    'country_name': 'Yemen',
#    'city': 'Al-Jin',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [35.361572, 35.927155]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 5,
#    'country_name': 'Syria',
#    'city': 'Jableh',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Business'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [34.516895, 69.147011]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 5,
#    'country_name': 'Afghanistan',
#    'city': 'Kabul',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Unknown'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [36.157001, 68.720306]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 5,
#    'country_name': 'Afghanistan',
#    'city': 'Khwajah Khan',
#    'attack_type': 'Assassination',
#    'target_type': 'Violent Political Party'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.802216, 74.940395]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 5,
#    'country_name': 'India',
#    'city': 'Chitragam',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Government (General)'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.890556, 62.406389]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 5,
#    'country_name': 'Afghanistan',
#    'city': 'Maldar',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [6.012985, 124.593255]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 5,
#    'country_name': 'Philippines',
#    'city': 'Nalus',
#    'attack_type': 'Facility/Infrastructure Attack',
#    'target_type': 'Transportation'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [31.026149, 62.450415]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 5,
#    'country_name': 'Afghanistan',
#    'city': 'Unknown',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Unknown'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [20.273183, 80.307383]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 5,
#    'country_name': 'India',
#    'city': 'Kehakavi',
#    'attack_type': 'Unknown',
#    'target_type': 'Violent Political Party'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [44.786568, 20.448922]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 5,
#    'country_name': 'Serbia',
#    'city': 'Belgrade',
#    'attack_type': 'Unknown',
#    'target_type': 'Journalists & Media'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [57.652828, 11.910749]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 5,
#    'country_name': 'Sweden',
#    'city': 'Gothenburg',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [6.545499, 101.2799]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 5,
#    'country_name': 'Thailand',
#    'city': 'Yala',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Educational Institution'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [2.973305, 45.535603]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 5,
#    'country_name': 'Somalia',
#    'city': 'Mahaday',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [15.325443, 44.211895]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 6,
#    'country_name': 'Yemen',
#    'city': 'Sanaa',
#    'attack_type': 'Hostage Taking (Barricade Incident)',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [25.831427, 62.259736]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 6,
#    'country_name': 'Pakistan',
#    'city': 'Bal',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [29.034412, 69.158661]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 6,
#    'country_name': 'Pakistan',
#    'city': 'Dera Bugti',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Unknown'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [28.923449, 69.001649]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 6,
#    'country_name': 'Pakistan',
#    'city': 'Patkhu',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Unknown'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.200819, 66.994354]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 6,
#    'country_name': 'Pakistan',
#    'city': 'Quetta',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [34.458889, 43.791004]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 6,
#    'country_name': 'Iraq',
#    'city': 'Dawr',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Police'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [35.392248, 68.222884]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 6,
#    'country_name': 'Afghanistan',
#    'city': 'Tala Wa Barfak district',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Business'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [1.978939, 44.832062]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 6,
#    'country_name': 'Somalia',
#    'city': 'Awdheegle',
#    'attack_type': 'Unknown',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [26.128364, 61.517983]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 6,
#    'country_name': 'Iran',
#    'city': 'Jakigour',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [24.383792, 94.148177]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 6,
#    'country_name': 'India',
#    'city': 'Nongkham Gamnon',
#    'attack_type': 'Assassination',
#    'target_type': 'Government (General)'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [24.891115, 67.143311]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 6,
#    'country_name': 'Pakistan',
#    'city': 'Karachi',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Police'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [26.071231, -80.145668]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 6,
#    'country_name': 'United States',
#    'city': 'Fort Lauderdale',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Airports & Aircraft'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [13.400089, 24.309717]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 6,
#    'country_name': 'Sudan',
#    'city': 'Keyo',
#    'attack_type': 'Hostage Taking (Kidnapping)',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [1.114228, 44.028706]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 6,
#    'country_name': 'Somalia',
#    'city': 'Barawe',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [34.458889, 43.791004]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 6,
#    'country_name': 'Iraq',
#    'city': 'Dawr',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [34.160587, 42.37254]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 6,
#    'country_name': 'Iraq',
#    'city': 'Hadithah',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [45.441025, 4.384553]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 6,
#    'country_name': 'France',
#    'city': 'Saint-Etienne',
#    'attack_type': 'Facility/Infrastructure Attack',
#    'target_type': 'Religious Figures/Institutions'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [13.750444, 121.377034]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 6,
#    'country_name': 'Philippines',
#    'city': 'San Juan district',
#    'attack_type': 'Assassination',
#    'target_type': 'Government (General)'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [12.407778, 123.405833]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 6,
#    'country_name': 'Philippines',
#    'city': 'Luy-a',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [24.891115, 67.143311]},
#   'properties': {'year': 2017,
#    'month': 1,
#    'day': 6,
#    'country_name': 'Pakistan',
#    'city': 'Karachi',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Police'}},
#  {'type': 'Feature',
# ...
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [36.354145, 43.14357]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 3,
#    'country_name': 'Iraq',
#    'city': 'Mosul',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Unknown'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [34.438844, 43.981389]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 3,
#    'country_name': 'Iraq',
#    'city': 'Ali Farhan',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [31.126646, 33.800865]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 3,
#    'country_name': 'Egypt',
#    'city': 'Arish',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Unknown'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [31.250196, 34.24128]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 3,
#    'country_name': 'Egypt',
#    'city': 'Rafah',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Educational Institution'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [31.132534, 64.212871]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 3,
#    'country_name': 'Afghanistan',
#    'city': 'Garmsir district',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Government (General)'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [31.132511, 64.212898]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 3,
#    'country_name': 'Afghanistan',
#    'city': 'Garmsir district',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Police'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [34.290942, 70.760212]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 3,
#    'country_name': 'Afghanistan',
#    'city': 'Sayed Ahmed',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Police'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [35.857001, 64.550338]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 2,
#    'country_name': 'Afghanistan',
#    'city': 'Almar district',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Police'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [8.245891, 34.591969]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 5,
#    'country_name': 'Ethiopia',
#    'city': 'Gambela',
#    'attack_type': 'Hostage Taking (Kidnapping)',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [7.73, 125.099]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 3,
#    'country_name': 'Philippines',
#    'city': 'Quezon district',
#    'attack_type': 'Assassination',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [34.110325, 71.163803]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 3,
#    'country_name': 'Pakistan',
#    'city': 'Landi Kotal',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [34.259016, 75.088856]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 3,
#    'country_name': 'India',
#    'city': 'Gund',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Unknown'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [32.006058, 35.125931]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 3,
#    'country_name': 'West Bank and Gaza Strip',
#    'city': 'Halamish',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Unknown'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [13.887403, 45.863647]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 3,
#    'country_name': 'Yemen',
#    'city': 'Lawdar',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Terrorists/Non-State Militia'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [13.357599, 45.69648]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 2,
#    'country_name': 'Yemen',
#    'city': 'Shoqra',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-5.340846, 12.341646]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 3,
#    'country_name': 'Angola',
#    'city': 'Unknown',
#    'attack_type': 'Unknown',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [31.117753, 34.080634]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 3,
#    'country_name': 'Egypt',
#    'city': 'Unknown',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Unknown'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [54.607712, -5.95621]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 3,
#    'country_name': 'United Kingdom',
#    'city': 'Belfast',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [6.611512, 122.263054]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 4,
#    'country_name': 'Philippines',
#    'city': 'Dugaa',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [6.611512, 122.263054]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 4,
#    'country_name': 'Philippines',
#    'city': 'Dugaa',
#    'attack_type': 'Assassination',
#    'target_type': 'Government (General)'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.038056, 40.284444]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 4,
#    'country_name': 'Iraq',
#    'city': 'Rutbah district',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Unknown'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.47327, 43.171093]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 4,
#    'country_name': 'Iraq',
#    'city': 'Albu Assaf',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Unknown'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.426758, 44.228073]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 4,
#    'country_name': 'Iraq',
#    'city': 'Al-Halabisah',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Unknown'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.426758, 44.228073]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 4,
#    'country_name': 'Iraq',
#    'city': 'Al-Halabisah',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Unknown'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.426758, 44.228073]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 4,
#    'country_name': 'Iraq',
#    'city': 'Al-Halabisah',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Unknown'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.426758, 44.228073]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 4,
#    'country_name': 'Iraq',
#    'city': 'Al-Halabisah',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Unknown'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.426758, 44.228073]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 4,
#    'country_name': 'Iraq',
#    'city': 'Al-Halabisah',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Unknown'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.426758, 44.228073]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 4,
#    'country_name': 'Iraq',
#    'city': 'Al-Halabisah',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Unknown'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.426758, 44.228073]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 4,
#    'country_name': 'Iraq',
#    'city': 'Al-Halabisah',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Unknown'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.426758, 44.228073]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 4,
#    'country_name': 'Iraq',
#    'city': 'Al-Halabisah',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Unknown'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.426758, 44.228073]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 4,
#    'country_name': 'Iraq',
#    'city': 'Al-Halabisah',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Unknown'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.426758, 44.228073]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 4,
#    'country_name': 'Iraq',
#    'city': 'Al-Halabisah',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Unknown'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.426758, 44.228073]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 4,
#    'country_name': 'Iraq',
#    'city': 'Al-Halabisah',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Unknown'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.426758, 44.228073]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 4,
#    'country_name': 'Iraq',
#    'city': 'Al-Halabisah',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Unknown'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.426758, 44.228073]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 4,
#    'country_name': 'Iraq',
#    'city': 'Al-Halabisah',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Unknown'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.426758, 44.228073]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 4,
#    'country_name': 'Iraq',
#    'city': 'Al-Halabisah',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Unknown'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.426758, 44.228073]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 4,
#    'country_name': 'Iraq',
#    'city': 'Al-Halabisah',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Unknown'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.426758, 44.228073]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 4,
#    'country_name': 'Iraq',
#    'city': 'Al-Halabisah',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Unknown'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.426758, 44.228073]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 4,
#    'country_name': 'Iraq',
#    'city': 'Al-Halabisah',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Unknown'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.426758, 44.228073]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 4,
#    'country_name': 'Iraq',
#    'city': 'Al-Halabisah',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Unknown'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.426758, 44.228073]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 4,
#    'country_name': 'Iraq',
#    'city': 'Al-Halabisah',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Unknown'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [31.126646, 33.800865]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 4,
#    'country_name': 'Egypt',
#    'city': 'Arish',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [31.126646, 33.800865]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 4,
#    'country_name': 'Egypt',
#    'city': 'Arish',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Educational Institution'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.049722, 68.645556]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 2,
#    'country_name': 'Afghanistan',
#    'city': 'Yosuf Khel district',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Religious Figures/Institutions'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [4.73538, 45.2024]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 4,
#    'country_name': 'Somalia',
#    'city': 'Beledweyne',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [13.887403, 45.863647]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 4,
#    'country_name': 'Yemen',
#    'city': 'Lawdar',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Police'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [36.376823, 42.448875]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 4,
#    'country_name': 'Iraq',
#    'city': 'Tal Afar',
#    'attack_type': 'Unknown',
#    'target_type': 'Police'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.669689, 44.381317]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 5,
#    'country_name': 'Iraq',
#    'city': 'Tarmiyah',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.303566, 44.371773]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 4,
#    'country_name': 'Iraq',
#    'city': 'Baghdad',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Transportation'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.303566, 44.371773]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 4,
#    'country_name': 'Iraq',
#    'city': 'Baghdad',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [15.914432, 2.397368]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 4,
#    'country_name': 'Mali',
#    'city': 'Menaka',
#    'attack_type': 'Armed Assault',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-0.975734, 29.062086]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 3,
#    'country_name': 'Democratic Republic of the Congo',
#    'city': 'Kikuku',
#    'attack_type': 'Unknown',
#    'target_type': 'Private Citizens & Property'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [24.798346, 93.94043]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 4,
#    'country_name': 'India',
#    'city': 'Imphal',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Business'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-0.249257, 42.601334]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 4,
#    'country_name': 'Somalia',
#    'city': 'Goob Weyn',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Military'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.303566, 44.371773]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 4,
#    'country_name': 'Iraq',
#    'city': 'Baghdad',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Business'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [33.303566, 44.371773]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 4,
#    'country_name': 'Iraq',
#    'city': 'Baghdad',
#    'attack_type': 'Bombing/Explosion',
#    'target_type': 'Business'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [32.760742, 21.757212]},
#   'properties': {'year': 2017,
#    'month': 2,
#    'day': 4,
#    'country_name': 'Libya',
#    'city': 'Beida',
#    'attack_type': 'Hostage Taking (Kidnapping)',
#    'target_type': 'Military'}},
#  ...]

# %%
col.aggregate()
