# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
terrorism_csv = pd.read_csv('test.csv', encoding = 'utf8')

# %%
terrorism_csv
# Out:
#         year  month  day  extended        country_name
# 0       1970      7    2         0  Dominican Republic
# 1       1970      0    0         0              Mexico
# 2       1970      1    0         0         Philippines
# 3       1970      1    0         0              Greece
# 4       1970      1    0         0               Japan
# 5       1970      1    1         0       United States
# 6       1970      1    2         0             Uruguay
# 7       1970      1    2         0       United States
# 8       1970      1    2         0       United States
# 9       1970      1    3         0       United States
# 10      1970      1    1         0       United States
# 11      1970      1    6         0       United States
# 12      1970      1    8         0               Italy
# 13      1970      1    9         0       United States
# 14      1970      1    9         0       United States
# 15      1970      1   10         0  East Germany (GDR)
# ...
