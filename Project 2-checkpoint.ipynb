# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
terrorism_csv = pd.read_csv("terrorism_cleanup.csv", encoding = 'latin-1')

# %%
terrorism_csv
# Out:
#         year  month  day        country_name  region  \
# 0       1970      7    2  Dominican Republic       2
# 1       1970      0    0              Mexico       1
# 2       1970      1    0         Philippines       5
# 3       1970      1    0              Greece       8
# 4       1970      1    0               Japan       4
# 5       1970      1    1       United States       1
# 6       1970      1    2             Uruguay       3
# 7       1970      1    2       United States       1
# 8       1970      1    2       United States       1
# 9       1970      1    3       United States       1
# 10      1970      1    1       United States       1
# 11      1970      1    6       United States       1
# 12      1970      1    8               Italy       8
# 13      1970      1    9       United States       1
# 14      1970      1    9       United States       1
# 15      1970      1   10  East Germany (GDR)       9
# 16      1970      1   11            Ethiopia      11
# ...
